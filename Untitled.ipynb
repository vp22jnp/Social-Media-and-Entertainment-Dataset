# %% [markdown]
# # Social media Usage analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('social_media_entertainment_data.csv')

# %%
df.head()
# Out:
#    User ID  Age  Gender  Country  Daily Social Media Time (hrs)  \
# 0        1   32   Other  Germany                           4.35
# 1        2   62   Other    India                           4.96
# 2        3   51  Female      USA                           6.78
# 3        4   44  Female    India                           5.06
# 4        5   21   Other  Germany                           2.57
#
#    Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# 0                            4.08                            5
# 1                            4.21                            2
# 2                            1.77                            4
# 3                            9.21                            3
# 4                            1.30                            4
#
#   Primary Platform  Daily Messaging Time (hrs)  \
# 0           TikTok                        0.35
# 1          YouTube                        2.55
# 2         Facebook                        2.09
# ...

# %%
df.dtypes
# Out:
# User ID                                         int64
# Age                                             int64
# Gender                                         object
# Country                                        object
# Daily Social Media Time (hrs)                 float64
# Daily Entertainment Time (hrs)                float64
# Social Media Platforms Used                     int64
# Primary Platform                               object
# Daily Messaging Time (hrs)                    float64
# Daily Video Content Time (hrs)                float64
# Daily Gaming Time (hrs)                       float64
# Occupation                                     object
# Marital Status                                 object
# Monthly Income (USD)                          float64
# Device Type                                    object
# Internet Speed (Mbps)                         float64
# Subscription Platforms                          int64
# ...

# %%
df.shape
# Out:
# (300000, 40)

# %%
df.columns.unique()
# Out:
# Index(['User ID', 'Age', 'Gender', 'Country', 'Daily Social Media Time (hrs)',
#        'Daily Entertainment Time (hrs)', 'Social Media Platforms Used',
#        'Primary Platform', 'Daily Messaging Time (hrs)',
#        'Daily Video Content Time (hrs)', 'Daily Gaming Time (hrs)',
#        'Occupation', 'Marital Status', 'Monthly Income (USD)', 'Device Type',
#        'Internet Speed (Mbps)', 'Subscription Platforms',
#        'Average Sleep Time (hrs)', 'Physical Activity Time (hrs)',
#        'Reading Time (hrs)', 'Work/Study Time (hrs)', 'Screen Time (hrs)',
#        'Notifications Received Daily', 'Daily Music Listening Time (hrs)',
#        'Preferred Content Type', 'Primary Social Media Goal',
#        'Preferred Entertainment Platform',
#        'Time Spent in Online Communities (hrs)',
#        'Social Media Fatigue Level (scale 1-10)',
#        'News Consumption Time (hrs)', 'Ad Interaction Count',
#        'Time on Educational Platforms (hrs)', 'Parental Status',
# ...

# %%
df['Primary Platform'].value_counts()
# Out:
# Primary Platform
# TikTok       60301
# Twitter      60285
# Facebook     59936
# YouTube      59757
# Instagram    59721
# Name: count, dtype: int64

# %% [markdown]
# # Check null values

# %%
df.isnull().sum()
# Out:
# User ID                                       0
# Age                                           0
# Gender                                        0
# Country                                       0
# Daily Social Media Time (hrs)                 0
# Daily Entertainment Time (hrs)                0
# Social Media Platforms Used                   0
# Primary Platform                              0
# Daily Messaging Time (hrs)                    0
# Daily Video Content Time (hrs)                0
# Daily Gaming Time (hrs)                       0
# Occupation                                    0
# Marital Status                                0
# Monthly Income (USD)                          0
# Device Type                                   0
# Internet Speed (Mbps)                         0
# Subscription Platforms                        0
# Average Sleep Time (hrs)                      0
# Physical Activity Time (hrs)                  0
# Reading Time (hrs)                            0
# ...

# %%
df.head(1)
# Out:
#    User ID  Age Gender  Country  Daily Social Media Time (hrs)  \
# 0        1   32  Other  Germany                           4.35
#
#    Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# 0                            4.08                            5
#
#   Primary Platform  Daily Messaging Time (hrs)  \
# 0           TikTok                        0.35
#
#    Daily Video Content Time (hrs)  ...  Ad Interaction Count  \
# 0                            5.43  ...                    20
#
#   Time on Educational Platforms (hrs) Parental Status  \
# 0                                4.11             Yes
#
#    Tech Savviness Level (scale 1-10) Preferred Device for Entertainment  \
# 0                                  9                             Tablet
#
#    Data Plan Used  Digital Well-being Awareness  Sleep Quality (scale 1-10)  \
# 0            50GB                      Moderate                           7
#
#    Social Isolation Feeling (scale 1-10)  \
# ...

# %%
ax=sns.countplot(data=df , x='Country', color='teal')

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '50060'),
#  Text(0, 0, '49924'),
#  Text(0, 0, '50145'),
#  Text(0, 0, '49910'),
#  Text(0, 0, '50040'),
#  Text(0, 0, '49921')]

# %% [markdown]
# # Whic platform used the most

# %%
ax=sns.countplot(data=df , x='Primary Platform', color='gold')

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '60301'),
#  Text(0, 0, '59757'),
#  Text(0, 0, '59936'),
#  Text(0, 0, '59721'),
#  Text(0, 0, '60285')]

# %% [raw]
# #Tiktok used most in all of these platform
# #approx equallY used all platforms

# %% [markdown]
# # What Devices used the most for entertainment

# %%
ax=sns.countplot(data=df , x='Preferred Device for Entertainment', color='cyan')

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '75001'),
#  Text(0, 0, '75184'),
#  Text(0, 0, '75252'),
#  Text(0, 0, '74563')]

# %% [raw]
# # As we can seee Smart phone prepfers most for entairtainment

# %% [markdown]
# # Gender Using social media most

# %%
ax=sns.countplot(data=df , x='Gender', color='olive')

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '100225'), Text(0, 0, '99873'), Text(0, 0, '99902')]

# %% [raw]
# Others are using most of the time social media

# %%
df.head()
# Out:
#    User ID  Age  Gender  Country  Daily Social Media Time (hrs)  \
# 0        1   32   Other  Germany                           4.35
# 1        2   62   Other    India                           4.96
# 2        3   51  Female      USA                           6.78
# 3        4   44  Female    India                           5.06
# 4        5   21   Other  Germany                           2.57
#
#    Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# 0                            4.08                            5
# 1                            4.21                            2
# 2                            1.77                            4
# 3                            9.21                            3
# 4                            1.30                            4
#
#   Primary Platform  Daily Messaging Time (hrs)  \
# 0           TikTok                        0.35
# 1          YouTube                        2.55
# 2         Facebook                        2.09
# ...

# %% [markdown]
# # Most platform used by country

# %%
Most_platform_used_by_country= df.groupby('Country')['Primary Platform'].value_counts().sort_values()
plt.figure(figsize=(20,5))
ax=Most_platform_used_by_country.plot(kind='bar',color=['red','green','teal','olive','gold'])

ax.bar_label(ax.containers[0])
plt.title('Most_platform_used_by_country')
# Out:
# Text(0.5, 1.0, 'Most_platform_used_by_country')

# %% [markdown]
# # Top 10 Platfrom users by Country

# %%
Most_platform_used_by_country = df.groupby('Country')['Primary Platform'].value_counts()
Most_platform_used_by_country = Most_platform_used_by_country.sort_values(ascending=False)
Top_10_platforms = Most_platform_used_by_country.head(10)
plt.figure(figsize=(20, 5))
ax = Top_10_platforms.plot(kind='bar', color='teal') 
ax.bar_label(ax.containers[0])  
plt.title('Top 10 Most Used Platforms by Country')
plt.xlabel('Country - Platform')
plt.ylabel('Counts')
plt.xticks(rotation=45, ha='right')
plt.tight_layout() 
plt.show()

# %% [markdown]
# # Time given on platform for entertainment purpose

# %%
Daily_Entertainment_Time_by_country= df.groupby('Country')['Daily Entertainment Time (hrs)'].mean().sort_values()
plt.figure(figsize=(15,5))
ax=Daily_Entertainment_Time_by_country.plot(kind='bar', color=['red','green','teal','olive','gold'])

ax.bar_label(ax.containers[0])
plt.title('Daily_Entertainment_Time_by_country')
# Out:
# Text(0.5, 1.0, 'Daily_Entertainment_Time_by_country')

# %% [markdown]
# # Average Daily Messaging Time hrs by country

# %%
Daily_Messaging_Time_hrs_by_country= df.groupby('Country')['Daily Messaging Time (hrs)'].mean().sort_values()
plt.figure(figsize=(15,5))
ax=Daily_Messaging_Time_hrs_by_country.plot(kind='bar',color=['red','green','teal','olive','gold'])

ax.bar_label(ax.containers[0])
plt.title('Daily_Messaging_Time_hrs_by_country')
# Out:
# Text(0.5, 1.0, 'Daily_Messaging_Time_hrs_by_country')

# %%
df.head()
# Out:
#    User ID  Age  Gender  Country  Daily Social Media Time (hrs)  \
# 0        1   32   Other  Germany                           4.35
# 1        2   62   Other    India                           4.96
# 2        3   51  Female      USA                           6.78
# 3        4   44  Female    India                           5.06
# 4        5   21   Other  Germany                           2.57
#
#    Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# 0                            4.08                            5
# 1                            4.21                            2
# 2                            1.77                            4
# 3                            9.21                            3
# 4                            1.30                            4
#
#   Primary Platform  Daily Messaging Time (hrs)  \
# 0           TikTok                        0.35
# 1          YouTube                        2.55
# 2         Facebook                        2.09
# ...

# %% [markdown]
# # Average Time on Educational Platforms by country

# %%
Time_on_Educational_Platforms_by_country= df.groupby('Country')['Time on Educational Platforms (hrs)'].mean().sort_values()
plt.figure(figsize=(15,5))
ax=Time_on_Educational_Platforms_by_country.plot(kind='bar',color=['red','green','teal','olive','gold'])

ax.bar_label(ax.containers[0])
plt.title('Time on Educational Platforms (hrs)')
# Out:
# Text(0.5, 1.0, 'Time on Educational Platforms (hrs)')

# %% [markdown]
# # Tech Savviness Level (scale 1-10)

# %%
plt.figure(figsize=(15,5))
ax=sns.countplot(data=df , x='Tech Savviness Level (scale 1-10)',color='gold')

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '32894'),
#  Text(0, 0, '33680'),
#  Text(0, 0, '33123'),
#  Text(0, 0, '33450'),
#  Text(0, 0, '33010'),
#  Text(0, 0, '33247'),
#  Text(0, 0, '33571'),
#  Text(0, 0, '33347'),
#  Text(0, 0, '33513'),
#  Text(0, 0, '165')]

# %% [markdown]
# # Average users age countrywise to use platforms

# %%
heatmap_data = df.groupby(['Country', 'Primary Platform'])['Age'].mean().unstack()
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="coolwarm", cbar_kws={'label': 'Age'})
# Out:
# <Axes: xlabel='Primary Platform', ylabel='Country'>

# %%
df.Age.unique()
# Out:
# array([32, 62, 51, 44, 21, 16, 58, 49, 14, 63, 56, 24, 22, 28, 40, 35, 20,
#        36, 53, 23, 39, 43, 15, 55, 18, 48, 19, 38, 60, 26, 47, 29, 41, 61,
#        59, 17, 33, 27, 31, 54, 64, 13, 50, 57, 45, 30, 46, 37, 52, 42, 25,
#        34, 65], dtype=int64)

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Country', y='Daily Social Media Time (hrs)', data=df, palette='viridis')
plt.xticks(rotation=45)
plt.title("Social Media Usage Distribution by Country")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15536\2481484391.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Country', y='Daily Social Media Time (hrs)', data=df, palette='viridis')

# %%
 plt.figure(figsize=(10, 6))

# Create a scatterplot
sns.scatterplot(data=df,  x='Screen Time (hrs)',  y='Social Isolation Feeling (scale 1-10)',alpha=0.5)
plt.title("Relationship between Screen Time and Social Isolation")
plt.grid(True, alpha=0.3)

# Display the plot
plt.show()

# %%
df.head()
# Out:
#    User ID  Age  Gender  Country  Daily Social Media Time (hrs)  \
# 0        1   32   Other  Germany                           4.35
# 1        2   62   Other    India                           4.96
# 2        3   51  Female      USA                           6.78
# 3        4   44  Female    India                           5.06
# 4        5   21   Other  Germany                           2.57
#
#    Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# 0                            4.08                            5
# 1                            4.21                            2
# 2                            1.77                            4
# 3                            9.21                            3
# 4                            1.30                            4
#
#   Primary Platform  Daily Messaging Time (hrs)  \
# 0           TikTok                        0.35
# 1          YouTube                        2.55
# 2         Facebook                        2.09
# ...

# %% [markdown]
# # Monthly Income (USD) Vs Daily Entertainment Time

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(data=df,x='Monthly Income (USD)',y='Daily Entertainment Time (hrs)', alpha=0.5)

plt.title("Monthly Income vs Total Entertainment Time")
plt.grid(True, alpha=0.3)


plt.show()

# %% [markdown]
# # Social Isolation Feeling (scale 1-10)

# %%
plt.figure(figsize=(15,5))
ax=sns.countplot(data=df , x='Social Isolation Feeling (scale 1-10)', color='gold')

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '33217'),
#  Text(0, 0, '33313'),
#  Text(0, 0, '33405'),
#  Text(0, 0, '33218'),
#  Text(0, 0, '33290'),
#  Text(0, 0, '33317'),
#  Text(0, 0, '33361'),
#  Text(0, 0, '33550'),
#  Text(0, 0, '33153'),
#  Text(0, 0, '176')]

# %%
df.columns.unique()
# Out:
# Index(['User ID', 'Age', 'Gender', 'Country', 'Daily Social Media Time (hrs)',
#        'Daily Entertainment Time (hrs)', 'Social Media Platforms Used',
#        'Primary Platform', 'Daily Messaging Time (hrs)',
#        'Daily Video Content Time (hrs)', 'Daily Gaming Time (hrs)',
#        'Occupation', 'Marital Status', 'Monthly Income (USD)', 'Device Type',
#        'Internet Speed (Mbps)', 'Subscription Platforms',
#        'Average Sleep Time (hrs)', 'Physical Activity Time (hrs)',
#        'Reading Time (hrs)', 'Work/Study Time (hrs)', 'Screen Time (hrs)',
#        'Notifications Received Daily', 'Daily Music Listening Time (hrs)',
#        'Preferred Content Type', 'Primary Social Media Goal',
#        'Preferred Entertainment Platform',
#        'Time Spent in Online Communities (hrs)',
#        'Social Media Fatigue Level (scale 1-10)',
#        'News Consumption Time (hrs)', 'Ad Interaction Count',
#        'Time on Educational Platforms (hrs)', 'Parental Status',
# ...

# %%
plt.figure(figsize=(15,5))
ax=sns.countplot(data=df , x='Subscription Platforms', color='pink')

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '49520'),
#  Text(0, 0, '50082'),
#  Text(0, 0, '50153'),
#  Text(0, 0, '49974'),
#  Text(0, 0, '50101'),
#  Text(0, 0, '50170')]

# %% [markdown]
# # Monthly income Vs occupation

# %%
plt.figure(figsize=(10, 6))

ax=sns.barplot(data=df,x='Occupation',y='Monthly Income (USD)', alpha=0.5)
ax.bar_label(ax.containers[0])
plt.title("Monthly Income vs Occupation")
plt.grid(True, alpha=0.3)


plt.show()

# %%
df['Monthly Income (USD)'].unique()
# Out:
# array([1838.33, 8352.  , 3698.74, ..., 7208.94, 4443.98, 1816.78])

# %% [markdown]
# # Preferred Platform used for entertainment

# %%
platform_counts = df['Preferred Entertainment Platform'].value_counts()
plt.figure(figsize=(4, 4))
platform_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colormap='tab20')
plt.title("Distribution of Platforms Used")
plt.axis('equal')
plt.show()

# %%
platform_counts = df['Preferred Device for Entertainment'].value_counts()
plt.figure(figsize=(4, 4))
platform_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colormap='tab20')
plt.title("Preferred Device for Entertainment")
plt.axis('equal')
plt.show()

# %%
df.head()
# Out:
#    User ID  Age  Gender  Country  Daily Social Media Time (hrs)  \
# 0        1   32   Other  Germany                           4.35
# 1        2   62   Other    India                           4.96
# 2        3   51  Female      USA                           6.78
# 3        4   44  Female    India                           5.06
# 4        5   21   Other  Germany                           2.57
#
#    Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# 0                            4.08                            5
# 1                            4.21                            2
# 2                            1.77                            4
# 3                            9.21                            3
# 4                            1.30                            4
#
#   Primary Platform  Daily Messaging Time (hrs)  \
# 0           TikTok                        0.35
# 1          YouTube                        2.55
# 2         Facebook                        2.09
# ...

# %% [markdown]
# # Top 10 Ages used for educational purpose

# %%
Top_10_age_used_on_educational_platforms = df.groupby('Age')['Time on Educational Platforms (hrs)'].mean()
Top_10_age_used_on_educational_platforms = Top_10_age_used_on_educational_platforms.sort_values(ascending=False)
Top_10_age_edu = Top_10_age_used_on_educational_platforms.head(10)
plt.figure(figsize=(20, 5))
ax = Top_10_age_edu.plot(kind='bar', color='teal') 
ax.bar_label(ax.containers[0])  
plt.title('Top_10_age_used_on_educational platforms')
plt.xlabel('Age')
plt.ylabel('Avg Time')
plt.xticks(rotation=45, ha='right')
plt.tight_layout() 
plt.show()

# %%
df['Primary Platform'].unique()
# Out:
# array(['TikTok', 'YouTube', 'Facebook', 'Instagram', 'Twitter'],
#       dtype=object)

# %% [markdown]
# # Top 10 age used social media for entertainment

# %%
Top_10_age_used_social_media_for_entertainement = df.groupby('Age')['Daily Social Media Time (hrs)'].mean()
Top_10_age_used_social_media_for_entertainement = Top_10_age_used_social_media_for_entertainement.sort_values(ascending=False)
Top_10_age = Top_10_age_used_social_media_for_entertainement.head(10)
plt.figure(figsize=(20, 5))
ax = Top_10_age.plot(kind='bar', color='teal') 
ax.bar_label(ax.containers[0])  
plt.title('Top_10_age_used_social_media_for_entertainement')
plt.xlabel('Age')
plt.ylabel('Avg Time')
plt.xticks(rotation=45, ha='right')
plt.tight_layout() 
plt.show()

# %% [markdown]
# # Conclusion

# %% [raw]
# # 1. Country Invoved Most : Germany , India , USA , Canada , UK , Austrailia
# # 2. Platform most Used : Twitter
# # 3. Device used Most : Smartphone
# # 4. Gender using most social media: Others
# # 5. Top platform users : Tik tok - USA
#                         # Twitter - USA
#                          # Twitter - Austrailia
#                          # Instagram - Germany
#                          # Twitter - India
